# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet('./../data/interim/aggregated.parquet')

# %%
df2 = pd.read_parquet('./../data/raw/weather_historical_forecast_hourly/year=2022.parquet')

# %%
df3 = pd.read_parquet('./../data/interim/aggregated.parquet')

# %%
df4 = pd.read_parquet('./../data/processed/features.parquet')

# %%
df4
# Out:
#                            load_load_mw  weather_basel__apparent_temperature  \
# 2022-01-08 00:00:00+00:00   7775.600000                            -2.157698
# 2022-01-08 01:00:00+00:00   8102.020000                            -1.988900
# 2022-01-08 02:00:00+00:00   8029.670000                            -1.925774
# 2022-01-08 03:00:00+00:00   7765.670000                            -1.436151
# 2022-01-08 04:00:00+00:00   7611.330000                            -2.426726
# ...                                 ...                                  ...
# 2026-04-19 16:00:00+00:00   6072.623046                            12.893927
# 2026-04-19 17:00:00+00:00   6457.772949                            12.542007
# 2026-04-19 18:00:00+00:00   6928.808105                            11.647262
# 2026-04-19 19:00:00+00:00   6198.979980                            10.409402
# 2026-04-19 20:00:00+00:00   7295.929687                             9.758240
#
# ...
